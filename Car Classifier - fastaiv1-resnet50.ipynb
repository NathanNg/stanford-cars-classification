# %% [markdown]
# # Stanford Car Classifier Model
# Model is built with fastai v1 and PyTorch v1, trained on Google Cloud Platform's Deep Learning
# Data Consist of 8144 Training Images

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#Import Libraries
from fastai.vision import *
from fastai.metrics import error_rate
from scipy.io import loadmat
import pandas as pd

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Download data from stanford.edu

# %%
#url = "http://imagenet.stanford.edu/internal/car196/cars_train"
#url_label = "https://ai.stanford.edu/~jkrause/cars/car_devkit"
car_path = Path('/home/jupyter/.fastai/data/car')

# path = untar_data(url);
# path_label = untar_data(url_label); path_label

car_train = Path(car_path/'cars_train');
car_test  = Path(car_path/'cars_test');
car_label = Path(car_path/'devkit');

# %%
## Training Data Cleaning
mat_data = loadmat(car_label/'cars_train_annos.mat')
mat_meta = loadmat(car_label/'cars_meta.mat')

# %%
mat_meta
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sat Dec 14 14:13:07 2013',
#  '__version__': '1.0',
#  '__globals__': [],
#  'class_names': array([[array(['AM General Hummer SUV 2000'], dtype='<U26'), array(['Acura RL Sedan 2012'], dtype='<U19'),
#          array(['Acura TL Sedan 2012'], dtype='<U19'), array(['Acura TL Type-S 2008'], dtype='<U20'), ...,
#          array(['Volvo C30 Hatchback 2012'], dtype='<U24'), array(['Volvo 240 Sedan 1993'], dtype='<U20'),
#          array(['Volvo XC90 SUV 2007'], dtype='<U19'), array(['smart fortwo Convertible 2012'], dtype='<U29')]],
#        dtype=object)}

# %%
class_id_label = mat_data['annotations']["class"].squeeze(); class_id_label
# Out:
# array([array([[14]], dtype=uint8), array([[3]], dtype=uint8), array([[91]], dtype=uint8), array([[134]], dtype=uint8),
#        ..., array([[196]], dtype=uint8), array([[163]], dtype=uint8), array([[112]], dtype=uint8),
#        array([[17]], dtype=uint8)], dtype=object)

# %%
fname = mat_data['annotations']['fname'].squeeze(); fname
# Out:
# array([array(['00001.jpg'], dtype='<U9'), array(['00002.jpg'], dtype='<U9'), array(['00003.jpg'], dtype='<U9'),
#        array(['00004.jpg'], dtype='<U9'), ..., array(['08141.jpg'], dtype='<U9'), array(['08142.jpg'], dtype='<U9'),
#        array(['08143.jpg'], dtype='<U9'), array(['08144.jpg'], dtype='<U9')], dtype=object)

# %%
class_names = mat_meta['class_names'].squeeze(); class_names
# Out:
# array([array(['AM General Hummer SUV 2000'], dtype='<U26'), array(['Acura RL Sedan 2012'], dtype='<U19'),
#        array(['Acura TL Sedan 2012'], dtype='<U19'), array(['Acura TL Type-S 2008'], dtype='<U20'), ...,
#        array(['Volvo C30 Hatchback 2012'], dtype='<U24'), array(['Volvo 240 Sedan 1993'], dtype='<U20'),
#        array(['Volvo XC90 SUV 2007'], dtype='<U19'), array(['smart fortwo Convertible 2012'], dtype='<U29')],
#       dtype=object)

# %%
class_id_label_list = [class_id[0][0] for class_id in class_id_label]; class_id_label_list[:5]
# Out:
# [14, 3, 91, 134, 106]

# %%
fname_list = [f[0] for f in fname]; fname_list[:5]
# Out:
# ['00001.jpg', '00002.jpg', '00003.jpg', '00004.jpg', '00005.jpg']

# %%
class_names_list = [c[0] for c in class_names]; class_names_list[:5]
# Out:
# ['AM General Hummer SUV 2000',
#  'Acura RL Sedan 2012',
#  'Acura TL Sedan 2012',
#  'Acura TL Type-S 2008',
#  'Acura TSX Sedan 2012']

# %%
#Mapping id to classnames for verboseness
class_name_label_list = [class_names_list[idx-1] for idx in class_id_label_list]; class_name_label_list[:5]
# Out:
# ['Audi TTS Coupe 2012',
#  'Acura TL Sedan 2012',
#  'Dodge Dakota Club Cab 2007',
#  'Hyundai Sonata Hybrid Sedan 2012',
#  'Ford F-450 Super Duty Crew Cab 2012']

# %%
train_df = pd.DataFrame(
            {'fname': fname_list,
             'label': class_name_label_list,
            })

# %%
train_df.head()
# Out:
#        fname                                label
# 0  00001.jpg                  Audi TTS Coupe 2012
# 1  00002.jpg                  Acura TL Sedan 2012
# 2  00003.jpg           Dodge Dakota Club Cab 2007
# 3  00004.jpg     Hyundai Sonata Hybrid Sedan 2012
# 4  00005.jpg  Ford F-450 Super Duty Crew Cab 2012

# %% [markdown]
# ## Preparing Test Data

# %%
car_path
# Out:
# PosixPath('/home/jupyter/.fastai/data/car')

# %%
#Download the data from source
#test_path = untar_data("http://imagenet.stanford.edu/internal/car196/cars_test")
#test_mat_path = Path(car_path/'devkit/cars_test_annos.mat')

test_path = Path(car_label/'cars_test')
test_mat_path = Path(car_path/'cars_test_annos_withlabels.mat')

# %%
test_mat_path
# Out:
# PosixPath('/home/jupyter/.fastai/data/car/cars_test_annos_withlabels.mat')

# %%
#mat_test = loadmat(path_label/'cars_test_annos.mat');mat_test
mat_test_label = loadmat(test_mat_path)

# %%
mat_test_label
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sat Dec 14 14:13:07 2013',
#  '__version__': '1.0',
#  '__globals__': [],
#  'annotations': array([[(array([[30]], dtype=uint8), array([[52]], dtype=uint8), array([[246]], dtype=uint8), array([[147]], dtype=uint8), array([[181]], dtype=uint8), array(['00001.jpg'], dtype='<U9')),
#          (array([[100]], dtype=uint8), array([[19]], dtype=uint8), array([[576]], dtype=uint16), array([[203]], dtype=uint8), array([[103]], dtype=uint8), array(['00002.jpg'], dtype='<U9')),
#          (array([[51]], dtype=uint8), array([[105]], dtype=uint8), array([[968]], dtype=uint16), array([[659]], dtype=uint16), array([[145]], dtype=uint8), array(['00003.jpg'], dtype='<U9')),
#          (array([[67]], dtype=uint8), array([[84]], dtype=uint8), array([[581]], dtype=uint16), array([[407]], dtype=uint16), array([[187]], dtype=uint8), array(['00004.jpg'], dtype='<U9')),
#          ...,
#          (array([[23]], dtype=uint8), array([[18]], dtype=uint8), array([[640]], dtype=uint16), array([[459]], dtype=uint16), array([[16]], dtype=uint8), array(['08038.jpg'], dtype='<U9')),
#          (array([[33]], dtype=uint8), array([[27]], dtype=uint8), array([[602]], dtype=uint16), array([[252]], dtype=uint8), array([[17]], dtype=uint8), array(['08039.jpg'], dtype='<U9')),
#          (array([[33]], dtype=uint8), array([[142]], dtype=uint8), array([[521]], dtype=uint16), array([[376]], dtype=uint16), array([[38]], dtype=uint8), array(['08040.jpg'], dtype='<U9')),
#          (array([[77]], dtype=uint8), array([[73]], dtype=uint8), array([[506]], dtype=uint16), array([[380]], dtype=uint16), array([[32]], dtype=uint8), array(['08041.jpg'], dtype='<U9'))]],
#        dtype=[('bbox_x1', 'O'), ('bbox_y1', 'O'), ('bbox_x2', 'O'), ('bbox_y2', 'O'), ('class', 'O'), ('fname', 'O')])}

# %%
test_id_label = mat_test_label['annotations']['class'].squeeze();test_id_label
# Out:
# array([array([[181]], dtype=uint8), array([[103]], dtype=uint8), array([[145]], dtype=uint8),
#        array([[187]], dtype=uint8), ..., array([[16]], dtype=uint8), array([[17]], dtype=uint8),
#        array([[38]], dtype=uint8), array([[32]], dtype=uint8)], dtype=object)

# %%
test_fname = mat_test_label['annotations']['fname'].squeeze(); test_fname
# Out:
# array([array(['00001.jpg'], dtype='<U9'), array(['00002.jpg'], dtype='<U9'), array(['00003.jpg'], dtype='<U9'),
#        array(['00004.jpg'], dtype='<U9'), ..., array(['08038.jpg'], dtype='<U9'), array(['08039.jpg'], dtype='<U9'),
#        array(['08040.jpg'], dtype='<U9'), array(['08041.jpg'], dtype='<U9')], dtype=object)

# %%
test_id_label_list = [class_id[0][0] for class_id in test_id_label]
test_fname_list = [f[0] for f in test_fname] 
class_names_list;

# Mapping id to classnames for verboseness
test_class_name_label_list = [class_names_list[idx-1] for idx in test_id_label_list] 

test_df = pd.DataFrame(
    {'fname': test_fname_list,
     'label': test_class_name_label_list,
    })

# %%
test_df.head()
# Out:
#        fname                                label
# 0  00001.jpg              Suzuki Aerio Sedan 2007
# 1  00002.jpg  Ferrari 458 Italia Convertible 2012
# 2  00003.jpg                Jeep Patriot SUV 2012
# 3  00004.jpg              Toyota Camry Sedan 2012
# 4  00005.jpg             Tesla Model S Sedan 2012

# %% [markdown]
# #Transform

# %%
#Transformation for Data Augmentation
arch = models.resnet50
arch_name = 'resnet50'
metric = [accuracy]
tfms = get_transforms()
size = 299
bs = 16

# %%
tfms
# Out:
# ([RandTransform(tfm=TfmCrop (crop_pad), kwargs={'row_pct': (0, 1), 'col_pct': (0, 1), 'padding_mode': 'reflection'}, p=1.0, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmPixel (flip_lr), kwargs={}, p=0.5, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmCoord (symmetric_warp), kwargs={'magnitude': (-0.2, 0.2)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmAffine (rotate), kwargs={'degrees': (-10.0, 10.0)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmAffine (zoom), kwargs={'scale': (1.0, 1.1), 'row_pct': (0, 1), 'col_pct': (0, 1)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmLighting (brightness), kwargs={'change': (0.4, 0.6)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmLighting (contrast), kwargs={'scale': (0.8, 1.25)}, p=0.75, resolved={}, do_run=True, is_random=True, use_on_y=True)],
#  [RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={}, do_run=True, is_random=True, use_on_y=True)])

# %%
data = (
    ImageList.from_df(df=train_df, path=car_train)
    .split_by_rand_pct(valid_pct=.2, seed=1010)
    .label_from_df(cols='label')
    .transform(tfms=tfms, size=size)
    .databunch(bs=bs)
)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (6516 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Audi TTS Coupe 2012,Acura TL Sedan 2012,Dodge Dakota Club Cab 2007,Hyundai Sonata Hybrid Sedan 2012,Ford F-450 Super Duty Crew Cab 2012
# Path: /home/jupyter/.fastai/data/car/cars_train;
#
# Valid: LabelList (1628 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Nissan 240SX Coupe 1998,Audi S5 Convertible 2012,Chevrolet Sonic Sedan 2012,Chevrolet Silverado 1500 Hybrid Crew Cab 2012,Mercedes-Benz S-Class Sedan 2012
# Path: /home/jupyter/.fastai/data/car/cars_train;
#
# Test: None

# %%
data.show_batch()

# %% [markdown]
# concanteaning traing and testing dataframes

# %%
df1 = train_df
train_df['is_valid'] = False
df2 = test_df
test_df['is_valid'] = True
full_df = pd.concat([df1,df2])

# %%
full_df.head()
# Out:
#        fname                                label  is_valid
# 0  00001.jpg                  Audi TTS Coupe 2012     False
# 1  00002.jpg                  Acura TL Sedan 2012     False
# 2  00003.jpg           Dodge Dakota Club Cab 2007     False
# 3  00004.jpg     Hyundai Sonata Hybrid Sedan 2012     False
# 4  00005.jpg  Ford F-450 Super Duty Crew Cab 2012     False

# %% [markdown]
# preparing test databunch

# %%
test_data = (ImageList.from_df(df=full_df, path=car_test)
            .split_from_df()
            .label_from_df(cols='label')
            .transform(tfms=tfms, size=size)
            .databunch(bs=bs)
            )

# %%
test_data
# Out:
# ImageDataBunch;
#
# Train: LabelList (8144 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Audi TTS Coupe 2012,Acura TL Sedan 2012,Dodge Dakota Club Cab 2007,Hyundai Sonata Hybrid Sedan 2012,Ford F-450 Super Duty Crew Cab 2012
# Path: /home/jupyter/.fastai/data/car/cars_test;
#
# Valid: LabelList (8041 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Suzuki Aerio Sedan 2007,Ferrari 458 Italia Convertible 2012,Jeep Patriot SUV 2012,Toyota Camry Sedan 2012,Tesla Model S Sedan 2012
# Path: /home/jupyter/.fastai/data/car/cars_test;
#
# Test: None

# %%
#learn = cnn_learner(data, models.resnet152, metrics=[accuracy])
learn = cnn_learner(data, arch, metrics=metric)

# %%
learn.summary()
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 150, 150]       9,408      False
# ______________________________________________________________________
# BatchNorm2d          [64, 150, 150]       128        True
# ______________________________________________________________________
# ReLU                 [64, 150, 150]       0          False
# ______________________________________________________________________
# MaxPool2d            [64, 75, 75]         0          False
# ______________________________________________________________________
# Conv2d               [64, 75, 75]         4,096      False
# ______________________________________________________________________
# BatchNorm2d          [64, 75, 75]         128        True
# ______________________________________________________________________
# Conv2d               [64, 75, 75]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 75, 75]         128        True
# ______________________________________________________________________
# Conv2d               [256, 75, 75]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 75, 75]        512        True
# ______________________________________________________________________
# ReLU                 [256, 75, 75]        0          False
# ______________________________________________________________________
# Conv2d               [256, 75, 75]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 75, 75]        512        True
# ______________________________________________________________________
# Conv2d               [64, 75, 75]         16,384     False
# ______________________________________________________________________
# BatchNorm2d          [64, 75, 75]         128        True
# ______________________________________________________________________
# Conv2d               [64, 75, 75]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 75, 75]         128        True
# ______________________________________________________________________
# Conv2d               [256, 75, 75]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 75, 75]        512        True
# ______________________________________________________________________
# ReLU                 [256, 75, 75]        0          False
# ______________________________________________________________________
# Conv2d               [64, 75, 75]         16,384     False
# ______________________________________________________________________
# BatchNorm2d          [64, 75, 75]         128        True
# ______________________________________________________________________
# Conv2d               [64, 75, 75]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 75, 75]         128        True
# ______________________________________________________________________
# Conv2d               [256, 75, 75]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 75, 75]        512        True
# ______________________________________________________________________
# ReLU                 [256, 75, 75]        0          False
# ______________________________________________________________________
# Conv2d               [128, 75, 75]        32,768     False
# ______________________________________________________________________
# BatchNorm2d          [128, 75, 75]        256        True
# ______________________________________________________________________
# Conv2d               [128, 38, 38]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 38, 38]        256        True
# ______________________________________________________________________
# Conv2d               [512, 38, 38]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 38, 38]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 38, 38]        0          False
# ______________________________________________________________________
# Conv2d               [512, 38, 38]        131,072    False
# ______________________________________________________________________
# BatchNorm2d          [512, 38, 38]        1,024      True
# ______________________________________________________________________
# Conv2d               [128, 38, 38]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [128, 38, 38]        256        True
# ______________________________________________________________________
# Conv2d               [128, 38, 38]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 38, 38]        256        True
# ______________________________________________________________________
# Conv2d               [512, 38, 38]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 38, 38]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 38, 38]        0          False
# ______________________________________________________________________
# Conv2d               [128, 38, 38]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [128, 38, 38]        256        True
# ______________________________________________________________________
# Conv2d               [128, 38, 38]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 38, 38]        256        True
# ______________________________________________________________________
# Conv2d               [512, 38, 38]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 38, 38]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 38, 38]        0          False
# ______________________________________________________________________
# Conv2d               [128, 38, 38]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [128, 38, 38]        256        True
# ______________________________________________________________________
# Conv2d               [128, 38, 38]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 38, 38]        256        True
# ______________________________________________________________________
# Conv2d               [512, 38, 38]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 38, 38]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 38, 38]        0          False
# ______________________________________________________________________
# Conv2d               [256, 38, 38]        131,072    False
# ______________________________________________________________________
# BatchNorm2d          [256, 38, 38]        512        True
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 19, 19]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 19, 19]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 19, 19]       0          False
# ______________________________________________________________________
# Conv2d               [1024, 19, 19]       524,288    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 19, 19]       2,048      True
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 19, 19]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 19, 19]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 19, 19]       0          False
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 19, 19]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 19, 19]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 19, 19]       0          False
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 19, 19]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 19, 19]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 19, 19]       0          False
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 19, 19]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 19, 19]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 19, 19]       0          False
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [256, 19, 19]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 19, 19]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 19, 19]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 19, 19]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 19, 19]       0          False
# ______________________________________________________________________
# Conv2d               [512, 19, 19]        524,288    False
# ______________________________________________________________________
# BatchNorm2d          [512, 19, 19]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 10, 10]        2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 10, 10]        1,024      True
# ______________________________________________________________________
# Conv2d               [2048, 10, 10]       1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 10, 10]       4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 10, 10]       0          False
# ______________________________________________________________________
# Conv2d               [2048, 10, 10]       2,097,152  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 10, 10]       4,096      True
# ______________________________________________________________________
# Conv2d               [512, 10, 10]        1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [512, 10, 10]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 10, 10]        2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 10, 10]        1,024      True
# ______________________________________________________________________
# Conv2d               [2048, 10, 10]       1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 10, 10]       4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 10, 10]       0          False
# ______________________________________________________________________
# Conv2d               [512, 10, 10]        1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [512, 10, 10]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 10, 10]        2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 10, 10]        1,024      True
# ______________________________________________________________________
# Conv2d               [2048, 10, 10]       1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 10, 10]       4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 10, 10]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# Flatten              [4096]               0          False
# ______________________________________________________________________
# BatchNorm1d          [4096]               8,192      True
# ______________________________________________________________________
# Dropout              [4096]               0          False
# ______________________________________________________________________
# Linear               [512]                2,097,664  True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [196]                100,548    True
# ______________________________________________________________________
#
# Total params: 25,715,460
# Total trainable params: 2,260,548
# Total non-trainable params: 23,454,912
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='90' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.11% [90/407 00:15<00:53 25.7286]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=slice(1e-3))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [8/10 08:08<02:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.003153</td>
#       <td>4.514495</td>
#       <td>0.089066</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.475120</td>
#       <td>3.438226</td>
#       <td>0.221130</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.450186</td>
#       <td>2.638492</td>
#       <td>0.361179</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.752014</td>
#       <td>2.150981</td>
#       <td>0.461302</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.257538</td>
#       <td>1.854231</td>
#       <td>0.528870</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.896861</td>
#       <td>1.599290</td>
#       <td>0.583538</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.499883</td>
#       <td>1.461722</td>
#       <td>0.620393</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.284278</td>
#       <td>1.372625</td>
#       <td>0.646806</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='369' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.66% [369/407 00:46<00:04 1.0903]
#     </div>

# %%
learn.save('car-'+ arch_name +'-299px-5ep-1e-3')

# %%
learn.validate(test_data.valid_dl)
# Out:
# [1.3063214, tensor(0.6586)]

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='72' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.69% [72/407 00:14<01:07 3.8847]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=slice(1e-6, 1e-3))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [9/10 11:59<01:19]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.034150</td>
#       <td>1.267428</td>
#       <td>0.667690</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.132378</td>
#       <td>1.224186</td>
#       <td>0.671376</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.242644</td>
#       <td>1.113985</td>
#       <td>0.691646</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.948586</td>
#       <td>0.976850</td>
#       <td>0.742629</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.760611</td>
#       <td>0.873076</td>
#       <td>0.768427</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.585331</td>
#       <td>0.809308</td>
#       <td>0.782555</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.389438</td>
#       <td>0.722748</td>
#       <td>0.801597</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.276896</td>
#       <td>0.676163</td>
#       <td>0.816953</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.208741</td>
#       <td>0.658100</td>
#       <td>0.821253</td>
#       <td>01:19</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='244' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       59.95% [244/407 00:43<00:28 0.2011]
#     </div>

# %%
learn.save('car-'+ arch_name +'-299-unfreeze-5ep-1e6-1e3')

# %%
learn.validate(test_data.valid_dl)
# Out:
# [0.6289406, tensor(0.8325)]

# %% [markdown]
# Add normalize imagenet stats

# %%
data_normalize = (
    ImageList.from_df(df=train_df, path=car_train)
    .split_by_rand_pct(valid_pct=.2, seed=1010)
    .label_from_df(cols='label')
    .transform(tfms=tfms, size=size)
    .databunch(bs=bs)
    .normalize(imagenet_stats)
)

# %%
test_data = (ImageList.from_df(df=full_df, path=car_test)
            .split_from_df()
            .label_from_df(cols='label')
            .transform(tfms=tfms, size=size)
            .databunch(bs=bs)
            .normalize(imagenet_stats)
            )

# %%
learn_normalize = cnn_learner(data, arch, metrics=metric)

# %%
learn_normalize.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='89' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.87% [89/407 00:12<00:43 21.3702]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_normalize.recorder.plot()

# %%
learn_normalize.fit_one_cycle(10, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [9/10 09:05<01:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.988472</td>
#       <td>4.481056</td>
#       <td>0.090909</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.183424</td>
#       <td>3.015130</td>
#       <td>0.285627</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.077152</td>
#       <td>2.108917</td>
#       <td>0.471744</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.275134</td>
#       <td>1.571650</td>
#       <td>0.594595</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.782054</td>
#       <td>1.327798</td>
#       <td>0.658477</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.389724</td>
#       <td>1.112638</td>
#       <td>0.700860</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.119866</td>
#       <td>0.972962</td>
#       <td>0.742629</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.833991</td>
#       <td>0.905795</td>
#       <td>0.756757</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.755763</td>
#       <td>0.869206</td>
#       <td>0.761671</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='210' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       51.60% [210/407 00:27<00:25 0.6812]
#     </div>

# %%
learn_normalize.save('car-'+ arch_name +'-normalize-299-5ep-1e-3')

# %%
learn_normalize.validate(test_data.valid_dl)
# Out:
# [15.194946, tensor(0.0076)]

# %%
learn_normalize.unfreeze()

# %%
learn_normalize.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='63' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.48% [63/407 00:12<01:06 2.6357]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_normalize.recorder.plot()

# %%
learn_normalize.fit_one_cycle(10,max_lr=(1e-4))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [9/10 11:58<01:19]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.705721</td>
#       <td>0.878702</td>
#       <td>0.754914</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.019310</td>
#       <td>0.982255</td>
#       <td>0.739558</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.032667</td>
#       <td>1.016396</td>
#       <td>0.713759</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.886044</td>
#       <td>0.877940</td>
#       <td>0.751843</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.706976</td>
#       <td>0.831483</td>
#       <td>0.778256</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.552030</td>
#       <td>0.630009</td>
#       <td>0.828624</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.347823</td>
#       <td>0.559109</td>
#       <td>0.845209</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.266563</td>
#       <td>0.502791</td>
#       <td>0.859337</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.197399</td>
#       <td>0.477337</td>
#       <td>0.859951</td>
#       <td>01:19</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='246' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.44% [246/407 00:43<00:28 0.1595]
#     </div>

# %%
learn_normalize.validate(test_data.valid_dl)
# Out:
# [12.42985, tensor(0.0086)]

# %%
learn_normalize.save('car-'+ arch_name +'-normalize-unfreeze-299-5ep-1e-4')

# %%
#Add resize_method=ResizeMethod.SQUISH to transform

# %%
data_normalize_tfms = (
    ImageList.from_df(df=train_df, path=car_train)
    .split_by_rand_pct(valid_pct=.2, seed=1010)
    .label_from_df(cols='label')
    .transform(tfms=tfms, size=size, resize_method=ResizeMethod.SQUISH, padding_mode='reflection')
    .databunch(bs=bs)
    .normalize(imagenet_stats)
)

# %%
learn_normalize_tfms=cnn_learner(data_normalize, arch, metrics=metric )

# %%
learn_normalize_tfms.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='89' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.87% [89/407 00:13<00:46 19.2132]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_normalize_tfms.recorder.plot()

# %%
learn_normalize_tfms.fit_one_cycle(10, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [9/10 09:09<01:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.895535</td>
#       <td>4.498568</td>
#       <td>0.093980</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.139241</td>
#       <td>2.980607</td>
#       <td>0.316339</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.929313</td>
#       <td>2.034399</td>
#       <td>0.493858</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.207834</td>
#       <td>1.582753</td>
#       <td>0.601966</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.729622</td>
#       <td>1.295346</td>
#       <td>0.672604</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.320695</td>
#       <td>1.063790</td>
#       <td>0.714988</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.049041</td>
#       <td>0.946348</td>
#       <td>0.737101</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.871612</td>
#       <td>0.893725</td>
#       <td>0.757985</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.761601</td>
#       <td>0.857082</td>
#       <td>0.772727</td>
#       <td>01:01</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='207' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.86% [207/407 00:26<00:25 0.7121]
#     </div>

# %%
learn_normalize_tfms.validate(test_data.valid_dl)
# Out:
# [0.8067969, tensor(0.7857)]

# %%
learn_normalize_tfms.save('car-'+ arch_name +'-normalize-tfms-299-5ep-1e-4')

# %%
learn_normalize_tfms.unfreeze()

# %%
learn_normalize_tfms.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='59' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.50% [59/407 00:11<01:08 1.9129]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_normalize_tfms.recorder.plot()

# %%
learn_normalize_tfms.fit_one_cycle(10,max_lr=1e-4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [9/10 11:58<01:19]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.676644</td>
#       <td>0.838014</td>
#       <td>0.777641</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.938340</td>
#       <td>1.009989</td>
#       <td>0.733415</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.126857</td>
#       <td>0.949915</td>
#       <td>0.738329</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.837125</td>
#       <td>0.821447</td>
#       <td>0.780098</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.683238</td>
#       <td>0.724649</td>
#       <td>0.797297</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.544616</td>
#       <td>0.644204</td>
#       <td>0.829238</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.344696</td>
#       <td>0.540073</td>
#       <td>0.846437</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.263637</td>
#       <td>0.505028</td>
#       <td>0.861179</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.202648</td>
#       <td>0.480369</td>
#       <td>0.864865</td>
#       <td>01:19</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='246' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.44% [246/407 00:43<00:28 0.1686]
#     </div>

# %%
learn_normalize_tfms.validate(test_data.valid_dl)
# Out:
# [0.43874404, tensor(0.8809)]

# %%
learn_normalize_tfms.save('car-'+ arch_name +'-normalize-tfms-unfreeze-299-5ep-1e-4')

# %% [markdown]
# Add Mixup to learner

# %%
data_normalize_mixup = (
    ImageList.from_df(df=train_df, path=car_train)
    .split_by_rand_pct(valid_pct=.2, seed=1010)
    .label_from_df(cols='label')
    .transform(tfms=tfms, size=size )
    .databunch(bs=bs)
    .normalize(imagenet_stats)
)

# %%
learn_normalize_tfms_mixup=cnn_learner(data_normalize_mixup, arch, metrics=metric).mixup()

# %%
learn_normalize_tfms_mixup.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='90' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.11% [90/407 00:12<00:43 26.9726]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_normalize_tfms_mixup.recorder.plot()

# %%
learn_normalize_tfms_mixup.fit_one_cycle(10, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [9/10 09:07<01:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.216092</td>
#       <td>4.695611</td>
#       <td>0.072482</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.900630</td>
#       <td>3.321847</td>
#       <td>0.240172</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.097925</td>
#       <td>2.441231</td>
#       <td>0.409705</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.560294</td>
#       <td>1.895022</td>
#       <td>0.528870</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.140226</td>
#       <td>1.534342</td>
#       <td>0.619779</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.779025</td>
#       <td>1.326849</td>
#       <td>0.664005</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.581972</td>
#       <td>1.185179</td>
#       <td>0.703931</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.477806</td>
#       <td>1.092556</td>
#       <td>0.726044</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.292583</td>
#       <td>1.044655</td>
#       <td>0.743243</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='217' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       53.32% [217/407 00:28<00:24 2.3276]
#     </div>

# %%
learn_normalize_tfms_mixup.save('car-'+ arch_name +'-normalize-mixup-299-5ep-1e-4')

# %%
learn_normalize_tfms_mixup.unfreeze()

# %%
learn_normalize_tfms_mixup.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='84' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.64% [84/407 00:15<01:00 7.1933]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_normalize_tfms_mixup.recorder.plot()

# %%
learn_normalize_tfms_mixup.fit_one_cycle(10, max_lr=slice(1e-6,1e-4))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [9/10 11:59<01:19]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.309143</td>
#       <td>1.016207</td>
#       <td>0.752457</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.245462</td>
#       <td>0.972002</td>
#       <td>0.750000</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.251240</td>
#       <td>0.937640</td>
#       <td>0.757985</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.182672</td>
#       <td>0.904236</td>
#       <td>0.772113</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.141537</td>
#       <td>0.858101</td>
#       <td>0.780713</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.052304</td>
#       <td>0.838759</td>
#       <td>0.784398</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.017878</td>
#       <td>0.807707</td>
#       <td>0.802211</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.958181</td>
#       <td>0.797319</td>
#       <td>0.805897</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.973437</td>
#       <td>0.784184</td>
#       <td>0.810197</td>
#       <td>01:19</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18' class='' max='407', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.42% [18/407 00:04<01:30 1.9714]
#     </div>

# %%
learn_normalize_tfms_mixup.save('car-'+ arch_name +'-normalize-mixup-unfreeze-299-5ep-1e-4')
